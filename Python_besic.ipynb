# %%
# 1 Write a code to create a string with your name and print it.

name = "Vishal ojha"
print(name)
# Out:
# Vishal ojha

# %%
# 2 Write a code to find the length of the string "Hello World".

Findlen = "Hello World"
print("Length of string:", len(Findlen))
# Out:
# Length of string: 11

# %%
# 3 Write a code to slice the first 3 characters from the string "Python Programming".

str = "Python programming"
first_three = str[ : 3]
print("First 3 character is:",first_three )
# Out:
# First 3 character is: Pyt

# %%
# 4 Write a code to convert the string "hello" to uppercase.

string = "hello"
uprcase = string.upper()
print("Uppercase:",uprcase)
# Out:
# Uppercase: HELLO

# %%
# 5 Write a code to replace the word "apple" with "orange" in the string "I like apple"

str = "I like apple"
new_str = str.replace("apple","orange")
print(new_str)
# Out:
# I like orange

# %%
# 6 Write a code to create a list with numbers 1 to 5 and print it

num = [1,2,3,4,5]
print(num)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 7 Write a code to append the number 10 to the list [1, 2, 3, 4]

num = [1,2,3,4]
num.append(10)
print(num)
# Out:
# [1, 2, 3, 4, 10]

# %%
# 8 Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]

num = [1,2,3,4,5]
num.remove(3)
print(num)
# Out:
# [1, 2, 4, 5]

# %%
# 9 Write a code to access the second element in the list ['a', 'b', 'c', 'd']

str = ['a','b','c','d']
sec_ele = str[1]
print(sec_ele)
# Out:
# b

# %%
# 10 Write a code to reverse the list [10, 20, 30, 40, 50].

str = [10, 20, 30, 40, 50]
rev_str = str[::-1]
print(rev_str)
# Out:
# [50, 40, 30, 20, 10]

# %%
# 11 . Write a code to create a tuple with the elements 100, 200, 300 and print it.

tup = 100,200,300
print(tup)
# Out:
# (100, 200, 300)

# %%
tup
# Out:
# (100, 200, 300)

# %%
# 12  Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').

colour = ('red', 'green', 'blue', 'yellow')
print(colour[2:])
# Out:
# ('blue', 'yellow')

# %%
# 13 Write a code to find the minimum number in the tuple (10, 20, 5, 15).

tup = (10, 20, 5, 15)
mini_num = min(tup)
print("Minimum number is:", mini_num )
# Out:
# Minimum number is: 5

# %%
# 14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').


tup = ('dog','cat','rabbit')
Cat_ind = tup.index('cat')
print("The cat index:",Cat_ind)
# Out:
# The cat index: 1

# %%
# 15. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.
fruits = ("Apple","Orange","Mango")
print("kiwi" in fruits)
# Out:
# False

# %%
# 16. Write a code to create a set with the elements 'a', 'b', 'c' and print it.

my_set = {'a', 'b', 'c'}
print(my_set)
# Out:
# {'a', 'c', 'b'}

# %%
# 17. Write a code to clear all elements from the set {1, 2, 3, 4, 5}.

my_set = {1, 2, 3, 4, 5}
my_set.clear()
print(my_set)
# Out:
# set()

# %%
# 18. Write a code to remove the element 4 from the set {1, 2, 3, 4}.

num = {1, 2, 3, 4}
num.remove(4)
print(num)
# Out:
# {1, 2, 3}

# %%
# 19. Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.

num1 = {1, 2, 3}
num2 = {3, 4, 5}
union_of_num = num1.union(num2)
print(union_of_num)
# Out:
# {1, 2, 3, 4, 5}

# %%
# 20. Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.

set1 = {1, 2, 3}
set2 = {2, 3, 4}
intersection = set1.intersection(set2)
print(intersection)
# Out:
# {2, 3}

# %%
# 21. Write a code to create a dictionary with the keys "name", "age", and "city", and print it.
dict = {"name":"Vishal", "age":"25", "city":"Dhanbad"}
print(dict)
# Out:
# {'name': 'Vishal', 'age': '25', 'city': 'Dhanbad'}

# %%
# 22. Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.

dict = {'name': 'John', 'age': 25}
dict["country"] = "USA"
print(dict)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
# 23. Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.

dict = {'name': 'Alice', 'age': 30}
print(dict['name'])
# Out:
# Alice

# %%
# 24. Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.

dict = {'name': 'Bob', 'age': 22, 'city': 'New York'}
dict.pop('age')
print(dict)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
# 25. Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.

dict = {'name': 'Alice', 'city': 'Paris'}

#check if condition

if "city" in dict:
  print("city is exists")
else:
  print("city does not exists")
# Out:
# city is exists

# %%
# 26. Write a code to create a list, a tuple, and a dictionary, and print them all.

All = ([1,2,"a"],('a','b',1,3),{"A":"a","B":"b","C":"c"})
print(All)
# Out:
# ([1, 2, 'a'], ('a', 'b', 1, 3), {'A': 'a', 'B': 'b', 'C': 'c'})

# %%
print(All[0])
# Out:
# [1, 2, 'a']

# %%
print(All[1])
# Out:
# ('a', 'b', 1, 3)

# %%
print(All[2])
# Out:
# {'A': 'a', 'B': 'b', 'C': 'c'}

# %%
# 27. Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.(replaced)


import random
# create 5 random number of list
numbers = [random.randint(1, 100) for _ in range(5)]

#s sort the list in acending order
numbers.sort()
#final result
print(numbers)
# Out:
# [14, 28, 38, 48, 52]

# %%
#28. Write a code to create a list with strings and print the element at the third index.

# Create a list of strings
fruits = ["Apple", "Banana", "Cherry", "Mango", "Orange"]

# Print the element at the third index
print("Element at third index:", fruits[3])
# Out:
# Element at third index: Mango

# %%
# 29. Write a code to combine two dictionaries into one and print the result.

# First dictionary
dict1 = {"name": "Alice","age": 25}

# Second dictionary
dict2 = {"city": "Paris","country": "France"}

# Combine the dictionaries
combined_dict = {**dict1, **dict2}

# Print the combined dictionary
print("Combined Dictionary:", combined_dict)
# Out:
# Combined Dictionary: {'name': 'Alice', 'age': 25, 'city': 'Paris', 'country': 'France'}

# %%
# #   30. Write a code to convert a list of strings into a set.


# Create a list of strings
fruits_list = ["Apple", "Banana", "Cherry", "Apple", "Mango"]

# Convert the list into a set
fruits_set = set(fruits_list)

# Print the set
print("Set:", fruits_set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1802/993156343.py in <cell line: 0>()
#       6
#       7 # Convert the list into a set
# ----> 8 fruits_set = set(fruits_list)
#       9
#      10 # Print the set
#
# TypeError: 'set' object is not callable
